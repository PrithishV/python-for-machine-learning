# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.452660 -1.644159  1.300971
# b       NaN       NaN       NaN
# c  0.917906 -0.815366  2.014357
# d  0.143540  0.598033  0.193565
# e       NaN       NaN       NaN
# f -1.046286 -2.100755  0.176990
#
#
# Dropped DataFrame
#          one       two     three
# a -0.452660 -1.644159  1.300971
# c  0.917906 -0.815366  2.014357
# d  0.143540  0.598033  0.193565
# f -1.046286 -2.100755  0.176990

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.882605 -0.415350 -0.369099
# b       NaN       NaN       NaN
# c -0.076469  0.167467 -0.370034
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.882605 -0.415350 -0.369099
# b  0.000000  0.000000  0.000000
# c -0.076469  0.167467 -0.370034

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  2.237494 -1.302158  1.522467
# b       NaN       NaN       NaN
# c -0.449977 -0.301830  0.258899
# d  0.288308  1.993434  1.284729
# e       NaN       NaN       NaN
# f -2.877321  1.907648  0.906716
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.985237  1.356596 -0.029427
# b       NaN       NaN       NaN
# c -0.904201 -0.681449  1.246662
# d -0.980392  0.294603 -1.023809
# e       NaN       NaN       NaN
# f  4.172338 -1.016730  0.397456
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.985237  1.356596 -0.029427
# b -0.904201 -0.681449  1.246662
# c -0.904201 -0.681449  1.246662
# d -0.980392  0.294603 -1.023809
# e  4.172338 -1.016730  0.397456
# f  4.172338 -1.016730  0.397456
